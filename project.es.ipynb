# %% [markdown]
# # Limpieza de bienes raíces
#
# Este es un conjunto de datos (dataset) reales que fue descargado usando técnicas de web scraping. La data contiene registros de **Fotocasa**, el cual es uno de los sitios más populares de bienes raíces en España. Por favor no hagas esto (web scraping) a no ser que sea para propósitos académicos.
#
# El dataset fue descargado hace algunos años por Henry Navarro y en ningún caso se obtuvo beneficio económico de ello.
#
# Contiene miles de datos de casas reales publicadas en la web www.fotocasa.com. Tu objetivo es extraer tanta información como sea posible con el conocimiento que tienes hasta ahora de ciencia de datos, por ejemplo ¿cuál es la casa más cara en todo el dataset?
#
# Empecemos precisamente con esa pregunta... ¡Buena suerte!

# %% [markdown]
# #### Ejercicio 00. Lee el dataset assets/real_estate.csv e intenta visualizar la tabla (★☆☆)

# %%
import pandas as pd

# Este archivo CSV contiene puntos y comas en lugar de comas como separadores
ds = pd.read_csv('assets/real_estate.csv', sep=';')
ds
# Out:
#        Unnamed: 0  id_realEstates  isNew                    realEstate_name  \
# 0               1       153771986  False            ferrari 57 inmobiliaria
# 1               2       153867863  False  tecnocasa fuenlabrada ferrocarril
# 2               3       153430440  False                 look find boadilla
# 3               4       152776331  False  tecnocasa fuenlabrada ferrocarril
# 4               5       153180188  False            ferrari 57 inmobiliaria
# ...           ...             ...    ...                                ...
# 15330       15331       153901377  False                infocasa consulting
# 15331       15332       150394373  False                inmobiliaria pulpon
# 15332       15333       153901397  False             tecnocasa torrelodones
# 15333       15334       152607440  False                inmobiliaria pulpon
# 15334       15335       153901356  False                infocasa consulting
#
# ...

# %% [markdown]
# #### Ejercicio 01. ¿Cuál es la casa más cara en todo el dataset? (★☆☆)
#
# Imprime la dirección y el precio de la casa seleccionada. Por ejemplo:
#
# `La casa con dirección en Calle del Prado, Nº20 es la más cara y su precio es de 5000000 USD`

# %%
# TODO
import pandas as pd # Importo la libreria de PANDAS
df = pd.read_csv('assets/real_estate.csv', sep=';') # Leo el archivo
orden = df.sort_values(by='price', ascending=False) # Organizo el archivo por precio, de mayor a menor
precio = orden['price'].iloc[0] # Traigo el precio que esta en primera posicion
direccion = orden['address'].iloc[0] # Traigo la direccion que esta en primera posicion
mensaje = f"La casa con direccion {direccion} es la mas cara y su precio es de {precio} USD" # Creo el mensaje y agrego las variables a la frase que se va a imprimir
print(mensaje) # Imprimo el mensaje
# Out:
# La casa con direccion El Escorial es la mas cara y su precio es de 8500000 USD

# %% [markdown]
# #### Ejercicio 02. ¿Cuál es la casa más barata del dataset? (★☆☆)
#
# Imprime la dirección y el precio de la casa seleccionada. Por ejemplo:
#
# `La casa con dirección en Calle Alcalá, Nº58 es la más barata y su precio es de 12000 USD`

# %%
# TODO
import pandas as pd # Importo la libreria de PANDAS
df = pd.read_csv('assets/real_estate.csv', sep=';') # Leo el archivo
orden = df.sort_values(by='price', ascending=True) # Organizo el archivo por precio, de menor a mayor
precio = orden['price'].iloc[0] # Traigo el precio que esta en primera posicion
direccion = orden['address'].iloc[0] # Traigo la direccion que esta en primera posicion
mensaje = f"La casa con direccion {direccion} es la mas barata y su precio es de {precio} USD" # Creo el mensaje y agrego las variables a la frase que se va a imprimir
print(mensaje) # Imprimo el mensaje
# Out:
# La casa con direccion  Madrid Capital es la mas barata y su precio es de 0 USD

# %% [markdown]
# #### Ejercicio 03. ¿Cuál es la casa más grande y la más pequeña del dataset? (★☆☆)
#
# Imprime la dirección y el área de las casas seleccionadas. Por ejemplo:
#
# `La casa más grande está ubicada en Calle Gran Vía, Nº38 y su superficie es de 5000 metros`
#
# `La casa más pequeña está ubicada en Calle Mayor, Nº12 y su superficie es de 200 metros`

# %%
# TODO
import pandas as pd # Importo la libreria de PANDAS
df = pd.read_csv('assets/real_estate.csv', sep=';') # Leo el archivo
orden = df.sort_values(by='surface', ascending=False) # Organizo el archivo por tamaño, de mayor a menor
tamano_mayor = orden['surface'].iloc[0] # Traigo el precio que esta en primera posicion
direccion_mayor = orden['address'].iloc[0] # Traigo la direccion que esta en primera posicion
tamano_menor = orden['surface'].iloc[-1] # Traigo el precio que esta en ultima posicion
direccion_menor = orden['address'].iloc[-1] # Traigo la direccion que esta en ultima posicion
mensaje1 = f"La casa más grande está ubicada en {direccion_mayor} y su superficie es de {tamano_mayor} metros" # Creo el mensaje y agrego las variables a la frase que se va a imprimir
mensaje2 = f"La casa más pequeña está ubicada en {direccion_menor} y su superficie es de {tamano_menor} metros" # Creo el mensaje y agrego las variables a la frase que se va a imprimir
print(mensaje1) # Imprimo el mensaje 1
print(mensaje2) # Imprimo el mensaje 2
# Out:
# La casa más grande está ubicada en Sevilla la Nueva y su superficie es de 249000.0 metros
# La casa más pequeña está ubicada en Calle de Manuela Malasaña,  Madrid Capital y su superficie es de nan metros

# %% [markdown]
# #### Ejercicio 04. ¿Cuantas poblaciones (columna level5) contiene el dataset? (★☆☆)
#
# Imprime el nombre de las poblaciones separadas por coma. Por ejemplo:
#
# `> print(populations)`
#
# `population1, population2, population3, ...`

# %%
# TODO
import pandas as pd # Importo la libreria de PANDAS
df = pd.read_csv('assets/real_estate.csv', sep=';') # Leo el archivo
orden = df.sort_values(by='level5', ascending=True) # Organizo el archivo por poblacion
poblaciones_unicas = orden['level5'].unique() # Obtengo las poblaciones sin repetir
poblaciones = ' , '.join(poblaciones_unicas) # Creo la variable donde junto las poblaciones unicas y separo por comas
poblaciones # Imprimo las poblaciones
# Out:
# ' Madrid Capital , Ajalvir , Alcalá de Henares , Alcobendas , Alcorcón , Aldea del Fresno , Algete , Alpedrete , Ambite , Anchuelo , Aranjuez , Arganda del Rey , Arroyomolinos (Madrid) , Batres , Becerril de la Sierra , Belmonte de Tajo , Boadilla del Monte , Braojos , Brea de Tajo , Brunete , Buitrago del Lozoya , Bustarviejo , Cabanillas de la Sierra , Cadalso de los Vidrios , Camarma de Esteruelas , Campo Real , Canencia , Carabaña , Casarrubuelos , Cenicientos , Cercedilla , Chapinería , Chinchón , Ciempozuelos , Cobeña , Collado Mediano , Collado Villalba , Colmenar Viejo , Colmenar de Oreja , Colmenar del Arroyo , Colmenarejo , Corpa , Coslada , Cubas de la Sagra , Daganzo de Arriba , El Atazar , El Berrueco , El Boalo - Cerceda – Mataelpino , El Escorial , El Molar (Madrid) , El Vellón , El Álamo , Estremera , Fresnedillas de la Oliva , Fresno de Torote , Fresno de Torote - Serracines , Fuenlabrada , Fuente El Saz de Jarama , Fuentidueña de Tajo , Galapagar , Garganta de los M
# ...

# %% [markdown]
# #### Ejercicio 05. ¿El dataset contiene valores no admitidos (NAs)? (★☆☆)
#
# Imprima un booleano (`True` o `False`) seguido de la fila/columna que contiene el NAs.

# %%
# TODO
import pandas as pd # Importo la libreria de PANDAS
import numpy as np # Importo la libreria NUMPY
df = pd.read_csv('assets/real_estate.csv', sep=';') # Leo el archivo
def valor(df): # Creo un funcion para ejecutar el for y el if
    for col in df.columns: # Consultamos sobre cada columna en el DF
        for i, value in enumerate(df[col]): # Pasamos por cada columna revisando los valores y obtenemos el indice (i) y el valor
            is_na = pd.isna(value) # Verificando si el valor es NA
print(f"Columna: {col}, Fila: {i+1}, Valor: {is_na}") 
valor(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 9
#       7         for i, value in enumerate(df[col]): # Pasamos por cada columna revisando los valores y obtenemos el indice (i) y el valor
#       8             is_na = pd.isna(value) # Verificando si el valor es NA
# ----> 9 print(f"Columna: {col}, Fila: {i+1}, Valor: {is_na}")
#      10 valor(df)
#
# NameError: name 'col' is not defined

# %% [markdown]
# #### Ejercicio 06. Elimina los NAs del dataset, si aplica (★★☆)
#
# Imprima una comparación entre las dimensiones del DataFrame original versus el DataFrame después de las eliminaciones.

# %%
# TODO
import pandas as pd # Importo la libreria de PANDAS
data = pd.read_csv('assets/real_estate.csv', sep=';')
df = pd.DataFrame(data)
print("DFInicial:", df.shape)
df_sin_na = df.copy()
df_sin_na.dropna(inplace=True)
print("DFfinal:", df_sin_na.shape)
print("DataFrame original:")
df
#print(df)
print("\nDataFrame sin NA:")
df_sin_na
#print(df_sin_na)
# Out:
# DFInicial: (15335, 37)
# DFfinal: (0, 37)
# DataFrame original:
#
# DataFrame sin NA:
# Empty DataFrame
# Columns: [Unnamed: 0, id_realEstates, isNew, realEstate_name, phone_realEstate, url_inmueble, rooms, bathrooms, surface, price, date, description, address, country, level1, level2, level3, level4, level5, level6, level7, level8, upperLevel, countryId, level1Id, level2Id, level3Id, level4Id, level5Id, level6Id, level7Id, level8Id, accuracy, latitude, longitude, zipCode, customZone]
# Index: []
#
# [0 rows x 37 columns]

# %% [markdown]
# #### Ejercicio 07. ¿Cuál la media de precios en la población (columna level5) de "Arroyomolinos (Madrid)"? (★★☆)
#
# Imprima el valor obtenido.

# %%
# TODO
import pandas as pd # Importo la libreria de PANDAS
df = pd.read_csv('assets/real_estate.csv', sep=';') # Leo el archivo
arroyomolinos_df = df[df['level5'] == 'Arroyomolinos (Madrid)']
media = arroyomolinos_df['price'].mean()
print (media)
# Out:
# 294541.59854014596

# %% [markdown]
# #### Ejercicio 08. Trazar el histograma de los precios para la población (level5 column) de "Arroyomolinos (Madrid)" y explica qué observas (★★☆)
#
# Imprime el histograma de los precios y escribe en la celda del Markdown un breve análisis del trazado.

# %%
# TODO: Code
import pandas as pd # Importo la libreria de PANDAS
import matplotlib.pyplot as plt
df = pd.read_csv('assets/real_estate.csv', sep=';') # Leo el archivo
arroyomolinos_df = df[df['level5'] == 'Arroyomolinos (Madrid)']
plt.hist(arroyomolinos_df['price'], bins=20, edgecolor='black')
plt.xlabel('Precio')
plt.ylabel('Frecuencia')
plt.title('Histograma de Precios en Arroyomolinos')
plt.show()

# %% [markdown]
# **TODO: Markdown**. La mayoria de precios que se manejan en Arroyomolinos son promedio, ocsilan entre los 200.000 y 400.000 dolares, el rango donde hay mas unidades habitacionales son en el rango de 200.000 a 300.000 dolares, se observan ciertas desviaciones a los lados pero mas con tendecia a la derecha que son valores mas elevados llegando aproximadamente a los 600.000 dolares, en resumen, hay variedad de precios en el sector de Arroyomolinos, la mayoria en el rango medio.

# %% [markdown]
# #### Ejercicio 09. ¿Son los precios promedios de "Valdemorillo" y "Galapagar" los mismos? (★★☆)
#
# Imprime ambos promedios y escribe una conclusión sobre ellos.

# %%
# TODO
import pandas as pd # Importo la libreria de PANDAS
df = pd.read_csv('assets/real_estate.csv', sep=';') # Leo el archivo
valdemorillo = df[df['level5'] == 'Valdemorillo']
galapagar = df[df['level5'] == 'Galapagar']
promvaldemorillo = valdemorillo['price'].mean()
promgalapagar = galapagar['price'].mean()
print(f"El precio promedio en Valdemorillo es: {promvaldemorillo}")
print(f"El precio promedio en Galapagar es: {promgalapagar}")
print(f"El precio promedio de las propiedades es muy similar, solo se nota una pequeña diferencia de 3.000 dolares en el valor de las propiedades a favor de Valdemorrillo")
# Out:
# El precio promedio en Valdemorillo es: 363860.2931034483
# El precio promedio en Galapagar es: 360063.20238095237
# El precio promedio de las propiedades esta muy similar, solo se nota una pequeña diferencia de 3.000 dolares en el valor de las propiedades a favor de Valdemorrillo

# %% [markdown]
# #### Ejercicio 10. ¿Son los promedios de precio por metro cuadrado (precio/m2) de "Valdemorillo" y "Galapagar" los mismos? (★★☆)
#
# Imprime ambos promedios de precio por metro cuadrado y escribe una conclusión sobre ellos.
#
# Pista: Crea una nueva columna llamada `pps` (*price per square* o precio por metro cuadrado) y luego analiza los valores.

# %%
# TODO
import pandas as pd # Importo la libreria de PANDAS
df = pd.read_csv('assets/real_estate.csv', sep=';') # Leo el archivo
df['pps'] = df['price'] / df['surface']
valdemorillo = df[df['level5'] == 'Valdemorillo']
galapagar = df[df['level5'] == 'Galapagar']
mt2promvaldemorillo = valdemorillo['pps'].mean()
mt2promgalapagar = galapagar['pps'].mean()
print(f"El precio promedio por metro cuadrado en Valdemorillo es: {mt2promvaldemorillo}")
print(f"El precio promedio por metro cuadrado en Galapagar es: {mt2promgalapagar}")
print(f"Analizando los valores se pude apreciar que los precios de Galapagar son mayores a los de Valdemorrillo, lo que indica que las viviendas en Valdemorrillo son mas grandes, pero la zona de las viviendas de Galapagar la hacen mas costosa, se recomienda revision de la zona para encontrar que incrementa su valoracioón")
# Out:
# El precio promedio por metro cuadrado en Valdemorillo es: 1317.9502109024986
# El precio promedio por metro cuadrado en Galapagar es: 1606.3240303094024
# Analizando los valores se pude pareciar que los precios de Galapagar son mayores a los de Valdemorrillo, lo que indica que las viviendas en Valdemorrillo son mas grandes, pero las viviendas de Galapagar tienen una caracteristica que llama mas la atencion que toca revisar la zona para ver que seria

# %% [markdown]
# #### Ejercicio 11. Analiza la relación entre la superficie y el precio de las casas. (★★☆)
#
# Pista: Puedes hacer un `scatter plot` y luego escribir una conclusión al respecto.

# %%
# TODO: Código
import pandas as pd # Importo la libreria de PANDAS
import matplotlib.pyplot as plt
df = pd.read_csv('assets/real_estate.csv', sep=';') # Leo el archivo
plt.scatter(df['surface'], df['price'])
plt.title('Relación entre Superficie y Precio')
plt.xlabel('Superficie')
plt.ylabel('Precio')
# Out:
# Text(0, 0.5, 'Precio')

# %% [markdown]
# **TODO: Markdown**. Vemos que no hay una relacion muy fuerte entre la superficie y el precio, hay otras variables que estan influyendo sobre el precio de los inmuebles, hay puntos especificos muy dispersos, pueden ser inmuebles especiales que tocaria identificar bien sus caracteristicas para poder determinar que sucede que apesar de tener gran tamaño su valor no es muy significativo, se debe realizar un analisis mas segmentado el cual permita ver mas a detalle las variaciones de los inmuebles de similar tamaño

# %% [markdown]
# #### Ejercicio 12. ¿Cuántas agencia de bienes raíces contiene el dataset? (★★☆)
#
# Imprime el valor obtenido.

# %%
# TODO
import pandas as pd
df = pd.read_csv('assets/real_estate.csv', sep=';') # Leo el archivo
agencias = df['realEstate_name'].nunique()
agencias
# Out:
# 1821

# %% [markdown]
# #### Ejercicio 13. ¿Cuál es la población (columna level5) que contiene la mayor cantidad de casas?(★★☆)
#
# Imprima la población y el número de casas.

# %%
# TODO
import pandas as pd
df = pd.read_csv('assets/real_estate.csv', sep=';')
casas = df.groupby('level5').size()
poblacion = casas.idxmax()
poblacion
# Out:
# ' Madrid Capital'

# %% [markdown]
# #### Ejercicio 14. Ahora vamos a trabajar con el "cinturón sur" de Madrid. Haz un subconjunto del DataFrame original que contenga las siguientes poblaciones (columna level5): "Fuenlabrada", "Leganés", "Getafe", "Alcorcón" (★★☆)
#
# Pista: Filtra el DataFrame original usando la columna `level5` y la función `isin`.

# %%
# TODO
import pandas as pd
df = pd.read_csv('assets/real_estate.csv', sep=';')
poblaciones = ['Fuenlabrada', 'Leganés', 'Getafe', 'Alcorcón']
subconjunto = df[df['level5'].isin(poblaciones)]
subconjunto
# Out:
#        Unnamed: 0  id_realEstates  isNew  \
# 1               2       153867863  False
# 3               4       152776331  False
# 85             86       153152077  False
# 94             95       153995577  False
# 109           110       153586414  False
# ...           ...             ...    ...
# 15275       15276       153903887  False
# 15291       15292       151697757  False
# 15305       15306       153902389  False
# 15322       15323       153871864  False
# 15325       15326       153901467  False
#
#                                  realEstate_name  phone_realEstate  \
# 1              tecnocasa fuenlabrada ferrocarril       916358736.0
# 3              tecnocasa fuenlabrada ferrocarril       916358736.0
# 85                       sinergical inmobiliaria               NaN
# 94                               viviendas365com       911226014.0
# 109              area uno asesores inmobiliarios       912664081.0
# ...

# %% [markdown]
# #### Ejercicio 15. Traza un gráfico de barras de la mediana de los precios y explica lo que observas (debes usar el subconjunto obtenido del Ejercicio 14) (★★★)
#
# Imprima un gráfico de barras de la mediana de precios y escriba en la celda Markdown un breve análisis sobre el gráfico.

# %%
# TODO: Code
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('assets/real_estate.csv', sep=';')
poblaciones = ['Fuenlabrada', 'Leganés', 'Getafe', 'Alcorcón']
subconjunto = df[df['level5'].isin(poblaciones)]
medianapoblacion = subconjunto.groupby('level5')['price'].median()
medianapoblacion.plot(kind='bar')
plt.title('Mediana de Precios por Población')
plt.xlabel('Población')
plt.ylabel('Precio Medio')
plt.show()

# %% [markdown]
# **TODO: Markdown**. Se destaca la poblacion de Getafe sobre las demas, presenta un precio medio muy superior a las otras 3 regiones, las otras 3 se mantienen en precios en la media, de estas 3 zonas se destaca Alcorón por estar un poco superior a las 3 y Fuenlabrada por ser la de menor valor de media

# %% [markdown]
# #### Ejercicio 16. Calcula la media y la varianza de muestra para las siguientes variables: precio, habitaciones, superficie y baños (debes usar el subconjunto obtenido del Ejercicio 14) (★★★)
#
# Imprime ambos valores por cada variable.

# %%
# TODO
import pandas as pd
df = pd.read_csv('assets/real_estate.csv', sep=';')
poblaciones = ['Fuenlabrada', 'Leganés', 'Getafe', 'Alcorcón']
subconjunto = df[df['level5'].isin(poblaciones)]
datos = subconjunto.groupby('level5')[['price', 'rooms', 'surface', 'bathrooms']].agg(['mean', 'var'])
datos
# Out:
#                      price                   rooms               surface  \
#                       mean           var      mean       var        mean
# level5
# Alcorcón     230071.052632  1.594783e+10  2.914894  0.933895  105.913295
# Fuenlabrada  177198.021459  4.701021e+09  3.025974  0.355844  103.624365
# Getafe       265040.500000  2.098267e+10  3.151724  0.772748  126.896266
# Leganés      208682.010309  1.191394e+10  2.906736  0.824590  105.852273
#
#                          bathrooms
#                      var      mean       var
# level5
# Alcorcón     4244.323834  1.623656  0.592735
# Fuenlabrada  2264.643893  1.445415  0.353367
# Getafe       5828.110028  1.865052  0.658809
# Leganés      3987.475195  1.518135  0.553055

# %% [markdown]
# #### Ejercicio 17. ¿Cuál es la casa más cara de cada población? Debes usar el subset obtenido en la pregunta 14 (★★☆)
#
# Imprime tanto la dirección como el precio de la casa seleccionada de cada población. Puedes imprimir un DataFrame o una sola línea para cada población.

# %%
# TODO
import pandas as pd
df = pd.read_csv('assets/real_estate.csv', sep=';')
poblaciones = ['Fuenlabrada', 'Leganés', 'Getafe', 'Alcorcón']
subconjunto = df[df['level5'].isin(poblaciones)]
precio = subconjunto.loc[subconjunto.groupby('level5')['price'].idxmax()]
print(precio[['address', 'price']])
# Out:
#                                      address    price
# 5585                                Alcorcón   950000
# 11561  Calle de Paulo Freire, 5, Fuenlabrada   490000
# 2881                                  Getafe  1050000
# 10412           Avenida Reina Sofía, Leganés   650000

# %% [markdown]
# #### Ejercicio 18. Normaliza la variable de precios para cada población y traza los 4 histogramas en el mismo gráfico (debes usar el subconjunto obtenido en la pregunta 14) (★★★)
#
# Para el método de normalización, puedes usar el que consideres adecuado, no hay una única respuesta correcta para esta pregunta. Imprime el gráfico y escribe en la celda de Markdown un breve análisis sobre el gráfico.
#
# Pista: Puedes ayudarte revisando la demostración multihist de Matplotlib.

# %%
# TODO
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('assets/real_estate.csv', sep=';')
poblaciones = ['Fuenlabrada', 'Leganés', 'Getafe', 'Alcorcón']
subconjunto = df[df['level5'].isin(poblaciones)]
subconjunto['price_normalized'] = subconjunto.groupby('level5')['price'].apply(lambda x: (x - x.min()) / (x.max() - x.min()))
fig, ax = plt.subplots()
for poblacion in poblaciones:
    subset = subconjunto[subconjunto['level5'] == poblacion]
    subset['price_normalized'].plot(kind='hist', bins=20, alpha=0.5, ax=ax, label=poblacion)
plt.title('Histogramas Normalizados de Precios por Población')
plt.xlabel('Precio Normalizado')
plt.ylabel('Frecuencia')
plt.legend()
plt.show()

# %% [markdown]
# **TODO: Markdown**. Para escribir aquí, haz doble clic en esta celda, elimina este contenido y coloca lo que quieras escribir. Luego ejecuta la celda.

# %% [markdown]
# #### Ejercicio 19. ¿Qué puedes decir sobre el precio por metro cuadrado (precio/m2) entre los municipios de 'Getafe' y 'Alcorcón'? Debes usar el subconjunto obtenido en la pregunta 14 (★★☆)
#
# Pista: Crea una nueva columna llamada `pps` (price per square en inglés) y luego analiza los valores

# %%
# TODO

# %% [markdown]
# #### Ejercicio 20. Realiza el mismo gráfico para 4 poblaciones diferentes (columna level5) y colócalos en el mismo gráfico. Debes usar el subconjunto obtenido en la pregunta 14 (★★☆)
# Pista: Haz un diagrama de dispersión de cada población usando subgráficos (subplots).

# %%
# TODO

# %% [markdown]
# #### Ejercicio 21. Realiza un trazado de las coordenadas (columnas latitud y longitud) del cinturón sur de Madrid por color de cada población (debes usar el subconjunto obtenido del Ejercicio 14) (★★★★)
#
# Ejecuta la siguiente celda y luego comienza a codear en la siguiente. Debes implementar un código simple que transforme las columnas de coordenadas en un diccionario de Python (agrega más información si es necesario) y agrégala al mapa.

# %%
from ipyleaflet import Map, basemaps

# Mapa centrado en (60 grados latitud y -2.2 grados longitud)
# Latitud, longitud
map = Map(center = (60, -2.2), zoom = 2, min_zoom = 1, max_zoom = 20, 
    basemap=basemaps.Stamen.Terrain)
map

# %%
## Aquí: traza la coordenadas de los estados

## PON TU CÓDIGO AQUÍ:
